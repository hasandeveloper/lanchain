# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import DatetimeOutputParser
# Out:
# /Users/apple/miniconda3/envs/langchain_env/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain_openai import ChatOpenAI
#       2 from langchain_core.messages import HumanMessage
# ----> 3 from langchain_core.output_parsers import DatetimeOutputParser
#
# ImportError: cannot import name 'DatetimeOutputParser' from 'langchain_core.output_parsers' (/Users/apple/miniconda3/envs/langchain_env/lib/python3.10/site-packages/langchain_core/output_parsers/__init__.py)
