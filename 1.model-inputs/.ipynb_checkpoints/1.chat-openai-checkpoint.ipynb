# %%
from langchain_openai import ChatOpenAI

chat = ChatOpenAI(
    model="gpt-4o-mini",      # change if you prefer another OpenAI chat model
    temperature=0,
    seed=365,
)
# Out:
# /Users/apple/miniconda3/envs/langchain_env/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
prompt = "I've recently adopted a dog. Could you suggest some dog names?"

response = chat.invoke(prompt)
response
# Out:
# AIMessage(content='Congratulations on your new furry friend! Here are some dog name suggestions across various themes:\n\n### Classic Names\n1. Max\n2. Bella\n3. Charlie\n4. Daisy\n5. Buddy\n\n### Unique Names\n1. Zephyr\n2. Nimbus\n3. Juno\n4. Koda\n5. Sable\n\n### Food-Inspired Names\n1. Biscuit\n2. Olive\n3. Mocha\n4. Peanut\n5. Honey\n\n### Nature-Inspired Names\n1. River\n2. Willow\n3. Ash\n4. Clover\n5. Storm\n\n### Pop Culture Names\n1. Yoda\n2. Arya\n3. Simba\n4. Frodo\n5. Luna\n\n### Fun and Quirky Names\n1. Waffles\n2. Noodle\n3. Pickles\n4. Tater Tot\n5. Snickers\n\n### Strong Names\n1. Thor\n2. Titan\n3. Rocco\n4. Athena\n5. Jax\n\nFeel free to mix and match or modify these names to find the perfect fit for your new companion!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 231, 'prompt_tokens': 20, 'total_tokens': 251, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_37b32d27ed', 'id': 'chatcmpl-DOIxBpfK7XUu9LU1P4VpimSq6iLyA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d3379-976b-79a2-82a5-f4dda3af3d01-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 231, 'total_tokens': 251, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(response.content)
# Out:
# Congratulations on your new furry friend! Here are some dog name suggestions across various themes:
#
# ### Classic Names
# 1. Max
# 2. Bella
# 3. Charlie
# 4. Daisy
# 5. Buddy
#
# ### Unique Names
# 1. Zephyr
# 2. Nimbus
# 3. Juno
# 4. Koda
# 5. Sable
#
# ### Food-Inspired Names
# 1. Biscuit
# 2. Olive
# 3. Mocha
# 4. Peanut
# 5. Honey
#
# ### Nature-Inspired Names
# 1. River
# 2. Willow
# 3. Ash
# 4. Clover
# 5. Storm
#
# ### Pop Culture Names
# 1. Yoda
# 2. Arya
# 3. Simba
# 4. Frodo
# 5. Luna
#
# ### Fun and Quirky Names
# 1. Waffles
# 2. Noodle
# 3. Pickles
# 4. Tater Tot
# 5. Snickers
#
# ### Strong Names
# 1. Thor
# 2. Titan
# 3. Rocco
# 4. Athena
# 5. Jax
#
# Feel free to mix and match or modify these names to find the perfect fit for your new companion!
